# %%
# !pip install dash
# Out:
# Requirement already satisfied: dash in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (1.19.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: flask-compress in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from dash) (1.15)
# Requirement already satisfied: plotly in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from dash) (5.22.0)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from dash) (1.9.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from dash) (4.11.2)
# Requirement already satisfied: future in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from dash) (1.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from Flask>=1.0.4->dash) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from Flask>=1.0.4->dash) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from Flask>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from Flask>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from Flask>=1.0.4->dash) (1.8.2)
# Requirement already satisfied: brotli in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flask-compress->dash) (1.1.0)
# Requirement already satisfied: zstandard in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from flask-compress->dash) (0.22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from plotly->dash) (8.3.0)
# Requirement already satisfied: packaging in c:\users\hp\appdata\roaming\python\python312\site-packages (from plotly->dash) (24.0)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python312\site-packages (from click>=8.1.3->Flask>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.0.4->dash) (2.1.5)

# %%
# !pip install werkzeug==2.0.3
# !pip uninstall werkzeug
# Out:
# ^C

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import dash
#       2 from dash import dcc, html
#       3 from dash.dependencies import Input, Output
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\dash\__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from . import dependencies  # noqa: F401,E402
#       7 from . import development  # noqa: F401,E402
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\dash\dash.py:22
#      20 import flask
#      21 from flask_compress import Compress
# ---> 22 from werkzeug.debug.tbtools import get_current_traceback
#      23 from pkg_resources import get_distribution, parse_version
#      25 import plotly
#
# ImportError: cannot import name 'get_current_traceback' from 'werkzeug.debug.tbtools' (c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\werkzeug\debug\tbtools.py)

# %%
# Load the data using pandas
data = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/historical_automobile_sales.csv')


# Initialize the Dash app
app = dash.Dash(__name__)

# List of years
year_list = [i for i in range(1980, 2024, 1)]

# Create the layout of the app
app.layout = html.Div([
    html.H1("Automobile Statistics Dashboard",
            style={'textAlign': 'center', 'color': 'red'}),
    html.Div([
        html.Div(
            html.Label("Select Statistics:",
                   style={ 'color': 'white','font-weight': 'bold','font': '18px Arial, Helvetica, sans-serif'}
                   ),
            style={'width': '60%','height':'30px','margin-left':'50px','padding':'15px'}

        ),

        dcc.Dropdown(
            id='select-statistics',
            options=[
                {'label': 'Yearly Statistics', 'value': 'Yearly Statistics'},
                {'label': 'Recession Period Statistics', 'value': 'Recession Period Statistics'}
            ],
            value='Yearly Statistics',
            placeholder='Select Statistics',
            style={
    'font-weight': 'bold',
    'font': '18px Arial, Helvetica, sans-serif'}
        )
    ]),
    html.Div(dcc.Dropdown(
            id='select-year',
            options=[{'label': i, 'value': i} for i in year_list],
            value=1980
        )),
    html.Div([
        html.Div(id='output-container', className='output-container', style={'width': '100%','margin':'auto', 'display': 'inline-block'}),
    ])
])

@app.callback(
    Output(component_id='select-year', component_property='disabled'),
    Input(component_id='select-statistics', component_property='value'))
def update_input_container(selected_statistics):
    if selected_statistics == 'Yearly Statistics':
        return False
    else:
        return True

@app.callback(
    Output(component_id='output-container', component_property='children'),
    [Input(component_id='select-statistics', component_property='value'),
    Input(component_id='select-year', component_property='value')])
def update_output_container(selected_statistics, input_year):
    if selected_statistics == 'Recession Period Statistics':
        recession_data = data[data['Recession'] == 1]

        # Example plot: Change this according to your specific needs
        plot1 = px.line(recession_data, x='Year', y='Automobile_Sales', title='Automobile Sales Over the Years During Recession')

        return [
            dcc.Graph(figure=plot1)
        ]
    elif input_year and selected_statistics == 'Yearly Statistics':
        yearly_data = data[data['Year'] == input_year]

        # Example plot: Change this according to your specific needs
        plot2 = px.bar(yearly_data, x='Month', y='Automobile_Sales', title=f'Automobile Sales in {input_year}')

        return [
            dcc.Graph(figure=plot2)
        ]
    else:
        return None

if __name__ == '__main__':
    app.run_server(mode='inline')
